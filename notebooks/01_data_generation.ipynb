# %%
import importlib
import src.components.data_ingestion as di
importlib.reload(di)
from src.components.data_ingestion import generate_leads

# %%
import sys
sys.path.append("/Workspace/Users/ajiboyeniola@gmail.com/lead-scoring")

from src.components.data_ingestion import generate_leads

# %%
df = generate_leads()

print(f"Dataset shape: {df.shape}")
print(f"Conversion rate: {df['converted'].mean() * 100:.2f}%")

# %%
display(df)

# %%
df.to_csv("/Workspace/Users/ajiboyeniola@gmail.com/lead-scoring/data/raw/leads.csv", index=False)
print("Data saved successfully")
